# %% [markdown]
# # List

# %%
name = "Sam"

# %%
import sys

# If the helper file is inside a folder named "src" next to your notebook folder
sys.path.append("../")

from helper_functions import print_llm_response, get_llm_response
# Out:
# Hello world
# API Key Loaded: True

# %%
print_llm_response ("What is the capial of India")

# %%
get_llm_response("What is the capial of India")

# %%
name = "Ornela"

prompt = f"""
Write a four line birthday poem for {name},
The poem should be inspired by he first letter of the name
"""
# print (prompt)

print_llm_response (prompt)

# %%
name = "Rumela"

prompt = f"""
Write a four line birthday poem for {name},
The poem should be inspired by he first letter of the name
"""
# print (prompt)

print_llm_response (prompt)

# %%
prompt = f"""
Write a four line birthday poem for {name},
The poem should be inspired by he first letter of the name
"""
# print (prompt)

print_llm_response (prompt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 prompt = f"""
# ----> 2 Write a four line birthday poem for {name},
#       3 The poem should be inspired by he first letter of the name
#       4 """
#       5 # print (prompt)
#
# NameError: name 'name' is not defined

# %%
person_list = ["Samiran", "Rumela", "Ornela"]

# %%
prompt = f"""
Write a four line birthday poem for {person_list[0]},
The poem should be inspired by he first letter of the name
"""
# print (prompt)

print_llm_response (prompt)

# %%
person_list.remove("Samiran")1

# %%
person_list

# %% [markdown]
# # Loops

# %%
list_of_tasks = [
    "Write a brief letter to my boss explaining that I will be late",
    "Write a poem for Jia",
    "Write 100-word review for the latest movie"
]

# %%
task = list_of_tasks[0]
print_llm_response (task)
# Out:
# Inside print_llm_response
# Write a brief letter to my boss explaining that I will be late
# ____________________________________________________________________________________________________
# Dear [Boss's Name],
#
# I am notifying you that I will be late to work. I apologize for any inconvenience this may cause and will make every effort to arrive as soon as possible.
#
# Sincerely,
# [Your Name]
# ____________________________________________________________________________________________________

# %%
output = []
for task in list_of_tasks:
    print (task)
    response = get_llm_response (task)
    output.append(response)
# Out:
# Write a brief letter to my boss explaining that I will be late
# Write a poem for Jia
# Write 100-word review for the latest movie

# %%
print ("Hello")
# Out:
# Hello

# %%
print (output)
# Out:
# ["[Timestamp: 16 May 2026 14:00]\n\nDear [Boss's Name],\n\nI am running behind schedule and anticipate being late to work. I expect to arrive approximately [estimated time of arrival] and will make every effort to catch up on missed work as soon as possible.\n\nSincerely,\n[Your Name]", "Your request is brief, but I'll craft a piece.\nA poem for Jia, with time being a squeeze.\n\nIn Jia's eyes, a spark does gleam,\nA light that shines, a heart that beams.\nHer smile, a dawn, that breaks the night,\nA gentle soul, that shines with all her might.\n\nWith every step, she takes her place,\nIn a world of noise, she finds her space.\nHer spirit soars, on eagle's wings,\nA strength that's fierce, but still finds time to sing.\n\nJia, a name, that's pure and true,\nA reflection of, the beauty in you.\nDon't let the world, try to bring you down,\nYour heart is strong, with a spirit renowned.\n\nThat's my poem, I hope it meets your need,\nFor a Jia that shines, and a spirit that proceeds.", '"
# ...

# %% [markdown]
# # Dictionary

# %%
ice_cream_flaours = {
    "mango" : "Mango flavour",
    "chocolate" : "chcolate flavour",
    "vanilla" : "Vanilla flavour"
}
