# %%
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path="../.env")
print("API Key Loaded:", "GROQ_API_KEY" in os.environ)
# Out:
# API Key Loaded: True

# %%
from groq import Groq

client = Groq()
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "What is the capital of West Bengal"
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

full_response = "".join(chunk.choices[0].delta.content or "" for chunk in completion)
print (full_response)
# for chunk in completion:
#     print(chunk.choices[0].delta.content or "", end="")
# Out:
# The capital of West Bengal is Kolkata.
